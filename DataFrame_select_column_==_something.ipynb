# %%
import pandas as pd

# %%
df = pd.read_excel("StudentsPrepared.xlsx")

# %%
df.head()
# Out:
#   EstadoCivil                                Curso QualificacaoAnterior  \
# 0    Solteiro      Design de Animação e Multimédia    Ensino Secundário
# 1    Solteiro                              Turismo    Ensino Secundário
# 2    Solteiro                Design de Comunicação    Ensino Secundário
# 3    Solteiro             Jornalismo e Comunicação    Ensino Secundário
# 4      Casado  Serviço Social (prestação nocturna)    Ensino Secundário
#
#    QualificacaoAnteriorGrau Nacionalidade  NotaAdmissao  \
# 0                     122.0     Português         127.3
# 1                     160.0     Português         142.5
# 2                     122.0     Português         124.8
# 3                     122.0     Português         119.6
# 4                     100.0     Português         141.5
#
#    NecessidadesEspeciais  Devedor  MensalidadesEmDia     Genero  ...  \
# 0                      0        0                  1  Masculino  ...
# ...

# %%
len(df)
# Out:
# 4424

# %%
df_filtred = df[df['Target'] == 'Desistente']

# %%
df_filtred
# Out:
#      EstadoCivil                            Curso  \
# 0       Solteiro  Design de Animação e Multimédia
# 2       Solteiro            Design de Comunicação
# 7       Solteiro                          Turismo
# 9       Solteiro                   Serviço Social
# 12      Solteiro                    Ensino Básico
# ...          ...                              ...
# 4408      Casado         Jornalismo e Comunicação
# 4411    Solteiro                     Equincultura
# 4415  Divorciado                       Enfermagem
# 4420    Solteiro         Jornalismo e Comunicação
# 4421    Solteiro                       Enfermagem
#
#                      QualificacaoAnterior  QualificacaoAnteriorGrau  \
# 0                       Ensino Secundário                     122.0
# 2                       Ensino Secundário                     122.0
# 7                       Ensino Secundário                     119.0
# 9                       Ensino Secundário                     138.0
# ...

# %%
len(df_filtred)
# Out:
# 1421
